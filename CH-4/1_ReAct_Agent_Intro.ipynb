# %% [markdown]
# TOOLS

# %%
from langchain_core.messages import HumanMessage,SystemMessage,AIMessage
from langchain_google_genai import ChatGoogleGenerativeAI

#llm = ChatGoogleGenerativeAI(model="gemini-3.1-flash-lite-preview",convert_system_message_to_human=True)
my_message=[
    SystemMessage(content="you are a gen-z assistant who always answers in funny way "),
    HumanMessage(content="brooo,tell me a fun fact")

]
#llm.invoke(my_message).content

# %%
#tool 1[News Search Tool]
from langchain_community.tools import DuckDuckGoSearchRun
search_tool=DuckDuckGoSearchRun(description="this is a tool tosearch the web for news ")
search_tool.invoke("who is neha?")
#tool 2:[WIKIPEDIA SEARCH TOOL]
from langchain_community.tools import WikipediaQueryRun
from langchain_community.utilities import WikipediaAPIWrapper
wikipedia_tool=WikipediaQueryRun(api_wrapper=WikipediaAPIWrapper(),description="this to is used to search wikipedia")

#TOOL 3:[CUSTOM ENTERPRISE TOOL]
from langchain.tools import tool
@tool
def enterprise_tool(query:str)->str:
    """this is a tool to send the emails to employees"""
    return "email sent"

# %%
ToolKit=[search_tool,wikipedia_tool,enterprise_tool]
ToolKit

# %%
from langchain.agents import create_pbi_agent

from langchain_google_genai import ChatGoogleGenerativeAI
model= ChatGoogleGenerativeAI(model="gemini-3.1-flash-lite-preview",temperature=0.1,max_tokens=1000,timeout=30)
agent = initialize_agen(model,tool=ToolKit)
agent
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 5
#       3 from langchain_google_genai import ChatGoogleGenerativeAI
#       4 model= ChatGoogleGenerativeAI(model="gemini-3.1-flash-lite-preview",temperature=0.1,max_tokens=1000,timeout=30)
# ----> 5 agent = create_react_agent(model,tool=ToolKit)
#       6 agent
#
# TypeError: create_react_agent() got an unexpected keyword argument 'tool'
