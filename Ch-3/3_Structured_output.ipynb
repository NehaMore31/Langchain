# %% [markdown]
# TypedDict
#
# this will give error only  if the datatypes are not same likewise

# %%
from typing import TypedDict
class llm_schema_td(TypedDict):
    setup:str
    punchline:str

obj=llm_schema_td({"ketchup":"some setup","punchline":"some punchline"})
obj
